# %%
#importing basic modules used in machine learning
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/Aeloori Revanth Kuma/Documents/forage/iris.csv')
df.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    150.000000   150.000000    150.000000   150.000000
# mean    75.500000      5.843333     3.057333      3.758000     1.199333
# std     43.445368      0.828066     0.435866      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
#checking null values
df.isna().sum()
# Out:
# Unnamed: 0      0
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
#printing class labels in the dataset
df['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# # Exploratory data analysis(EDA) and Data Preprocessing

# %%
#ploting all the numerical attributes using boxplot for finding outliers

plt.figure(figsize=(14,8))
plt.subplot(2,2,1)
sns.boxplot(df['Sepal.Length'])
plt.title('Sepal Lenght')
plt.grid()
plt.subplot(2,2,2)
sns.boxplot(df['Sepal.Width'])
plt.title('Sepal  width')
plt.grid()
plt.subplot(2,2,3)
plt.title('Petal.length')
sns.boxplot(df['Petal.Length'])
plt.grid()
plt.subplot(2,2,4)
plt.title('Petal width')
sns.boxplot(df['Petal.Width'])
plt.grid()

# %%
#removing outliers and unrelevant attribute

for i in range(len(df)):
    if (df['Sepal.Width'][i]<=2.0 or df['Sepal.Width'][i]>4.0):
        df['Sepal.Width'][i]=df['Sepal.Width'][i].mean()
df.drop(df.columns[0],axis=1,inplace=True)
df.head()
# Out:
# C:\Users\Aeloori Revanth Kuma\AppData\Local\Temp\ipykernel_11560\2109790235.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sepal.Width'][i]=df['Sepal.Width'][i].mean()
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
#Frequency of each class label in the dataset
sns.countplot(data=df,x='Species')
plt.grid()

# %%
#normal distribution of numerical attributes

plt.figure(figsize=(14,10))
plt.subplot(2,2,1)
sns.distplot(df['Sepal.Length'])
plt.title('Sepal Lenght')
plt.subplot(2,2,2)
sns.distplot(df['Sepal.Width'])
plt.title('Sepal  width')
plt.subplot(2,2,3)
plt.title('Petal.length')
sns.distplot(df['Petal.Length'])
plt.subplot(2,2,4)
plt.title('Petal width')
sns.distplot(df['Petal.Width'])
# Out:
# C:\Users\Aeloori Revanth Kuma\AppData\Local\Temp\ipykernel_11560\3848534111.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sepal.Length'])
# C:\Users\Aeloori Revanth Kuma\AppData\Local\Temp\ipykernel_11560\3848534111.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#correlation among the numerical attributes
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Aeloori Revanth Kuma\AppData\Local\Temp\ipykernel_11560\3222596027.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# # Building model

# %%
# modules used for model building
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve

# %%
x=df.drop(columns='Species',axis=1)
y=df[['Species']]

# %%
#Splitting data into training and testing

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=20,random_state=42)

# %%
#Building model using Decision Tree

dt=DecisionTreeClassifier(criterion='gini')
dt.fit(xtrain,ytrain)
ypred=dt.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
cm=confusion_matrix(ytest,ypred)

# %%
cn=['setosa', 'versicolor', 'virginica']
ind=[0,1,2]
ax=sns.heatmap(cm,annot=True)
ax.set_xticklabels(cn)
ax.set_yticklabels(cn)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Confusion matrix')
# Out:
# Text(0.5, 1.0, 'Confusion matrix')

# %%
ac=accuracy_score(ytest,ypred)

# %%
#Accuracy

print('Accuracy:',ac*100)
print("classification report:\n",classification_report(ytest,ypred))
# Out:
# Accuracy: 100.0
# classification report:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         6
#   versicolor       1.00      1.00      1.00         9
#    virginica       1.00      1.00      1.00         5
#
#     accuracy                           1.00        20
#    macro avg       1.00      1.00      1.00        20
# weighted avg       1.00      1.00      1.00        20

# %%
#Classify data 

print('Enter Sepal length, Sepal Width, Petal Lenght, Petal width of a flower respectively:')
a=float(input())
b=float(input())
c=float(input())
d=float(input())
dic={"Sepal.Length":[a],"Sepal.Width":[b],"Petal.Length":[c],"Petal.Width":[d]}
test=pd.DataFrame(dic)
print("Predicted Flower type:",dt.predict(test)[0])
# Out:
# Enter Sepal length, Sepal Width, Petal Lenght, Petal width of a flower respectively:
